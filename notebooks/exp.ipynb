# %%
import pandas as pd
df=pd.read_csv("data\dataset-of-90s.csv")

# %%
df["target"].value_counts()
# Out:
# target
# 0    2760
# 1    2760
# Name: count, dtype: int64

# %%
import os
list_of_file=[file_name for file_name in os.listdir("data") if file_name.endswith(".csv")]

# %%
list_of_file=list_of_file[:-1]

# %%
df2000=pd.read_csv(f"data/{list_of_file[0]}")
df2010=pd.read_csv(f"data/{list_of_file[1]}")
df1960=pd.read_csv(f"data/{list_of_file[2]}")
df1970=pd.read_csv(f"data/{list_of_file[3]}")
df1980=pd.read_csv(f"data/{list_of_file[4]}")
df1990=pd.read_csv(f"data/{list_of_file[5]}")

# %%
df = pd.concat([pd.read_csv(f"data/{file}") for file in list_of_file], ignore_index=True)

# %%
len(df)
# Out:
# 41106

# %%
df.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994    4    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764    2    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0289      0.368000           0.00000     0.159    0.532
# 1     0       0.1830      0.018500           0.00000     0.148    0.688
# 2     1       0.0473      0.000111           0.00457     0.174    0.300
# 3     1       0.1660      0.000007           0.07840     0.192    0.333
# 4     1       0.0275      0.363000           0.00000     0.125    0.631
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target
# 0  133.061       196707               4    30.88059        13       1
# 1   92.988       242587               4    41.51106        10       1
# 2   86.964       338893               4    65.32887        13       0
# 3  148.440       255667               4    58.59528         9       0
# 4  112.098       193760               4    22.62384        10       1

# %%
df.to_csv("data/spotify.csv",index=False)

# %%
import numpy as np
test=np.load("C:/Vscode/git/mlops/Spotify_tracks_classification/artifacts/08_19_2025_21_05_37/data_transformation/transformed_data/transformed_test_data.npz")
print(test["y"].reshape(-1).shape)
# Out:
# (12332,)

# %%
import pymongo
import pandas as pd

df=pd.read_csv("data/spotify.csv")
df.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994    4    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764    2    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0289      0.368000           0.00000     0.159    0.532
# 1     0       0.1830      0.018500           0.00000     0.148    0.688
# 2     1       0.0473      0.000111           0.00457     0.174    0.300
# 3     1       0.1660      0.000007           0.07840     0.192    0.333
# 4     1       0.0275      0.363000           0.00000     0.125    0.631
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target
# 0  133.061       196707               4    30.88059        13       1
# 1   92.988       242587               4    41.51106        10       1
# 2   86.964       338893               4    65.32887        13       0
# 3  148.440       255667               4    58.59528         9       0
# 4  112.098       193760               4    22.62384        10       1

# %%
spotify_dict=df.to_dict(orient="records")

# %%
spotify_dict
# Out:
# [{'track': 'Lucky Man',
#   'artist': 'Montgomery Gentry',
#   'uri': 'spotify:track:4GiXBCUF7H6YfNQsnBRIzl',
#   'danceability': 0.578,
#   'energy': 0.471,
#   'key': 4,
#   'loudness': -7.27,
#   'mode': 1,
#   'speechiness': 0.0289,
#   'acousticness': 0.368,
#   'instrumentalness': 0.0,
#   'liveness': 0.159,
#   'valence': 0.532,
#   'tempo': 133.061,
#   'duration_ms': 196707,
#   'time_signature': 4,
#   'chorus_hit': 30.88059,
#   'sections': 13,
#   'target': 1},
#  {'track': 'On The Hotline',
#   'artist': 'Pretty Ricky',
#   'uri': 'spotify:track:1zyqZONW985Cs4osz9wlsu',
#   'danceability': 0.704,
#   'energy': 0.854,
#   'key': 10,
#   'loudness': -5.477,
#   'mode': 0,
#   'speechiness': 0.183,
#   'acousticness': 0.0185,
#   'instrumentalness': 0.0,
#   'liveness': 0.148,
#   'valence': 0.688,
#   'tempo': 92.988,
#   'duration_ms': 242587,
#   'time_signature': 4,
#   'chorus_hit': 41.51106,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Clouds Of Dementia',
#   'artist': 'Candlemass',
#   'uri': 'spotify:track:6cHZf7RbxXCKwEkgAZT4mY',
#   'danceability': 0.162,
#   'energy': 0.836,
#   'key': 9,
#   'loudness': -3.009,
#   'mode': 1,
#   'speechiness': 0.0473,
#   'acousticness': 0.000111,
#   'instrumentalness': 0.00457,
#   'liveness': 0.174,
#   'valence': 0.3,
#   'tempo': 86.964,
#   'duration_ms': 338893,
#   'time_signature': 4,
#   'chorus_hit': 65.32887,
#   'sections': 13,
#   'target': 0},
#  {'track': 'Heavy Metal, Raise Hell!',
#   'artist': 'Zwartketterij',
#   'uri': 'spotify:track:2IjBPp2vMeX7LggzRN3iSX',
#   'danceability': 0.188,
#   'energy': 0.994,
#   'key': 4,
#   'loudness': -3.745,
#   'mode': 1,
#   'speechiness': 0.166,
#   'acousticness': 7.39e-06,
#   'instrumentalness': 0.0784,
#   'liveness': 0.192,
#   'valence': 0.333,
#   'tempo': 148.44,
#   'duration_ms': 255667,
#   'time_signature': 4,
#   'chorus_hit': 58.59528,
#   'sections': 9,
#   'target': 0},
#  {'track': "I Got A Feelin'",
#   'artist': 'Billy Currington',
#   'uri': 'spotify:track:1tF370eYXUcWwkIvaq3IGz',
#   'danceability': 0.63,
#   'energy': 0.764,
#   'key': 2,
#   'loudness': -4.353,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.363,
#   'instrumentalness': 0.0,
#   'liveness': 0.125,
#   'valence': 0.631,
#   'tempo': 112.098,
#   'duration_ms': 193760,
#   'time_signature': 4,
#   'chorus_hit': 22.62384,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Dantzig Station',
#   'artist': 'State Of Art',
#   'uri': 'spotify:track:5Z3nrC0JbJmXaOGiXTuNFk',
#   'danceability': 0.726,
#   'energy': 0.837,
#   'key': 11,
#   'loudness': -7.223,
#   'mode': 0,
#   'speechiness': 0.0965,
#   'acousticness': 0.373,
#   'instrumentalness': 0.268,
#   'liveness': 0.136,
#   'valence': 0.969,
#   'tempo': 135.347,
#   'duration_ms': 192720,
#   'time_signature': 4,
#   'chorus_hit': 28.29051,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Divorced',
#   'artist': 'Blacklisted',
#   'uri': 'spotify:track:0iAdSLiQBIizTAiLUP7p5E',
#   'danceability': 0.365,
#   'energy': 0.922,
#   'key': 1,
#   'loudness': -2.644,
#   'mode': 1,
#   'speechiness': 0.071,
#   'acousticness': 0.00285,
#   'instrumentalness': 0.0,
#   'liveness': 0.321,
#   'valence': 0.29,
#   'tempo': 77.25,
#   'duration_ms': 89427,
#   'time_signature': 4,
#   'chorus_hit': 45.77202,
#   'sections': 4,
#   'target': 0},
#  {'track': 'Where I Come From',
#   'artist': 'Alan Jackson',
#   'uri': 'spotify:track:6ej1QJ8eIYmhsyTlvgDajy',
#   'danceability': 0.726,
#   'energy': 0.631,
#   'key': 11,
#   'loudness': -8.136,
#   'mode': 0,
#   'speechiness': 0.0334,
#   'acousticness': 0.22,
#   'instrumentalness': 0.0,
#   'liveness': 0.193,
#   'valence': 0.746,
#   'tempo': 124.711,
#   'duration_ms': 239240,
#   'time_signature': 4,
#   'chorus_hit': 35.59732,
#   'sections': 10,
#   'target': 1},
#  {'track': "Nothin' To Die For",
#   'artist': 'Tim McGraw',
#   'uri': 'spotify:track:3lRSz6HujrSy9b3LXg2Kq9',
#   'danceability': 0.481,
#   'energy': 0.786,
#   'key': 10,
#   'loudness': -5.654,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.0538,
#   'instrumentalness': 0.0,
#   'liveness': 0.0759,
#   'valence': 0.389,
#   'tempo': 153.105,
#   'duration_ms': 253640,
#   'time_signature': 4,
#   'chorus_hit': 19.65701,
#   'sections': 11,
#   'target': 1},
#  {'track': 'I Want to Know Your Plans',
#   'artist': 'Say Anything',
#   'uri': 'spotify:track:3pjnCLIHbRczUjenWOEo56',
#   'danceability': 0.647,
#   'energy': 0.324,
#   'key': 7,
#   'loudness': -9.679,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 0.354,
#   'instrumentalness': 0.0,
#   'liveness': 0.115,
#   'valence': 0.344,
#   'tempo': 124.213,
#   'duration_ms': 314286,
#   'time_signature': 3,
#   'chorus_hit': 32.66343,
#   'sections': 16,
#   'target': 0},
#  {'track': 'F.U.R.B. (F U Right Back)',
#   'artist': 'Frankee',
#   'uri': 'spotify:track:7jElrCgQJBcVLsbMRKni2t',
#   'danceability': 0.787,
#   'energy': 0.632,
#   'key': 8,
#   'loudness': -3.487,
#   'mode': 1,
#   'speechiness': 0.137,
#   'acousticness': 0.103,
#   'instrumentalness': 6.78e-06,
#   'liveness': 0.388,
#   'valence': 0.612,
#   'tempo': 141.026,
#   'duration_ms': 198173,
#   'time_signature': 4,
#   'chorus_hit': 18.091,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Amarillo Sky',
#   'artist': 'Jason Aldean',
#   'uri': 'spotify:track:0axUHkhMMY0YSC1jFBVWqv',
#   'danceability': 0.491,
#   'energy': 0.776,
#   'key': 2,
#   'loudness': -3.887,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.314,
#   'instrumentalness': 0.0,
#   'liveness': 0.146,
#   'valence': 0.428,
#   'tempo': 154.988,
#   'duration_ms': 202547,
#   'time_signature': 4,
#   'chorus_hit': 37.86861,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Gin And Juice',
#   'artist': 'Hot Rod Circuit',
#   'uri': 'spotify:track:1xthH0Ze4FYo2y99QuJUUj',
#   'danceability': 0.455,
#   'energy': 0.737,
#   'key': 1,
#   'loudness': -6.206,
#   'mode': 1,
#   'speechiness': 0.0272,
#   'acousticness': 0.00114,
#   'instrumentalness': 0.000487,
#   'liveness': 0.195,
#   'valence': 0.206,
#   'tempo': 94.028,
#   'duration_ms': 224053,
#   'time_signature': 4,
#   'chorus_hit': 62.77759,
#   'sections': 9,
#   'target': 0},
#  {'track': 'Six-Pack Summer',
#   'artist': 'Phil Vassar',
#   'uri': 'spotify:track:23qDMWnwf8p0pr5slljB6i',
#   'danceability': 0.725,
#   'energy': 0.733,
#   'key': 0,
#   'loudness': -6.66,
#   'mode': 1,
#   'speechiness': 0.0242,
#   'acousticness': 0.508,
#   'instrumentalness': 0.0,
#   'liveness': 0.173,
#   'valence': 0.843,
#   'tempo': 100.311,
#   'duration_ms': 219827,
#   'time_signature': 4,
#   'chorus_hit': 27.0663,
#   'sections': 8,
#   'target': 1},
#  {'track': 'Hatho Pai Kariya Na Kar',
#   'artist': 'Kartar Ramla',
#   'uri': 'spotify:track:7KA8tQVcGqCHHdGwSCRi6v',
#   'danceability': 0.497,
#   'energy': 0.421,
#   'key': 2,
#   'loudness': -14.059,
#   'mode': 0,
#   'speechiness': 0.187,
#   'acousticness': 0.985,
#   'instrumentalness': 0.839,
#   'liveness': 0.148,
#   'valence': 0.804,
#   'tempo': 92.19,
#   'duration_ms': 232719,
#   'time_signature': 4,
#   'chorus_hit': 33.3613,
#   'sections': 15,
#   'target': 0},
#  {'track': 'Serious Hardcore - Original Mix',
#   'artist': 'Ham',
#   'uri': 'spotify:track:6mGnxmegYYJA2TkhXCbOkb',
#   'danceability': 0.509,
#   'energy': 0.942,
#   'key': 11,
#   'loudness': -6.899,
#   'mode': 1,
#   'speechiness': 0.0628,
#   'acousticness': 0.000639,
#   'instrumentalness': 0.882,
#   'liveness': 0.0788,
#   'valence': 0.163,
#   'tempo': 169.96,
#   'duration_ms': 460080,
#   'time_signature': 4,
#   'chorus_hit': 34.78597,
#   'sections': 12,
#   'target': 0},
#  {'track': "Daddy Won't Sell The Farm",
#   'artist': 'Montgomery Gentry',
#   'uri': 'spotify:track:2Wt173KM9i97KSB52qCuqj',
#   'danceability': 0.708,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -7.039,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.011,
#   'instrumentalness': 2.26e-05,
#   'liveness': 0.0556,
#   'valence': 0.704,
#   'tempo': 119.881,
#   'duration_ms': 258640,
#   'time_signature': 4,
#   'chorus_hit': 33.81641,
#   'sections': 15,
#   'target': 1},
#  {'track': 'Move Along',
#   'artist': 'The All-American Rejects',
#   'uri': 'spotify:track:2l57cfmCnOkwNX1tky02n1',
#   'danceability': 0.518,
#   'energy': 0.916,
#   'key': 3,
#   'loudness': -3.858,
#   'mode': 1,
#   'speechiness': 0.0454,
#   'acousticness': 0.000148,
#   'instrumentalness': 0.0,
#   'liveness': 0.291,
#   'valence': 0.646,
#   'tempo': 109.864,
#   'duration_ms': 238880,
#   'time_signature': 4,
#   'chorus_hit': 19.81215,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Era De Maggio',
#   'artist': 'Tito Schipa',
#   'uri': 'spotify:track:1YJ7qQEFIkh2r8VEb5X8lp',
#   'danceability': 0.395,
#   'energy': 0.248,
#   'key': 1,
#   'loudness': -10.025,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.979,
#   'instrumentalness': 0.0,
#   'liveness': 0.177,
#   'valence': 0.324,
#   'tempo': 85.174,
#   'duration_ms': 207888,
#   'time_signature': 3,
#   'chorus_hit': 34.50252,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Apply Some Pressure',
#   'artist': 'Maximo Park',
#   'uri': 'spotify:track:19503qDaxgCdPL2BhJngij',
#   'danceability': 0.378,
#   'energy': 0.953,
#   'key': 9,
#   'loudness': -3.632,
#   'mode': 1,
#   'speechiness': 0.138,
#   'acousticness': 0.000719,
#   'instrumentalness': 2.89e-05,
#   'liveness': 0.0936,
#   'valence': 0.512,
#   'tempo': 167.808,
#   'duration_ms': 200347,
#   'time_signature': 4,
#   'chorus_hit': 20.58661,
#   'sections': 12,
#   'target': 0},
#  {'track': "It's So Hard",
#   'artist': 'Big Punisher Featuring Donell Jones',
#   'uri': 'spotify:track:5NQdweL8O7nGdM7e4IS1lf',
#   'danceability': 0.9,
#   'energy': 0.593,
#   'key': 10,
#   'loudness': -6.629,
#   'mode': 0,
#   'speechiness': 0.333,
#   'acousticness': 0.0554,
#   'instrumentalness': 0.0,
#   'liveness': 0.0304,
#   'valence': 0.633,
#   'tempo': 92.946,
#   'duration_ms': 172933,
#   'time_signature': 4,
#   'chorus_hit': 21.78144,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Celtic Pride',
#   'artist': 'The Mahones',
#   'uri': 'spotify:track:2lAbqS3XIaHpZyhwW3pMjg',
#   'danceability': 0.329,
#   'energy': 0.812,
#   'key': 2,
#   'loudness': -11.48,
#   'mode': 1,
#   'speechiness': 0.0872,
#   'acousticness': 0.0141,
#   'instrumentalness': 0.0786,
#   'liveness': 0.0603,
#   'valence': 0.4,
#   'tempo': 165.013,
#   'duration_ms': 272880,
#   'time_signature': 4,
#   'chorus_hit': 97.84874,
#   'sections': 9,
#   'target': 0},
#  {'track': 'Birth Interlude',
#   'artist': 'Clubroot',
#   'uri': 'spotify:track:4wuqqKXIbFBB8MX0EYpj96',
#   'danceability': 0.389,
#   'energy': 0.598,
#   'key': 4,
#   'loudness': -8.473,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.782,
#   'instrumentalness': 0.948,
#   'liveness': 0.0825,
#   'valence': 0.0396,
#   'tempo': 140.002,
#   'duration_ms': 226147,
#   'time_signature': 4,
#   'chorus_hit': 22.35533,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Make It Rain',
#   'artist': 'Fat Joe Featuring Lil Wayne',
#   'uri': 'spotify:track:1Ji8DhJGIQuV9kBiTgcChh',
#   'danceability': 0.744,
#   'energy': 0.697,
#   'key': 11,
#   'loudness': -5.063,
#   'mode': 0,
#   'speechiness': 0.197,
#   'acousticness': 0.0106,
#   'instrumentalness': 0.0,
#   'liveness': 0.0842,
#   'valence': 0.767,
#   'tempo': 149.28,
#   'duration_ms': 247413,
#   'time_signature': 4,
#   'chorus_hit': 42.63475,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Here Comes The Summer',
#   'artist': 'The Fiery Furnaces',
#   'uri': 'spotify:track:257xjCQOUQaSOwQWw9fTe1',
#   'danceability': 0.723,
#   'energy': 0.785,
#   'key': 5,
#   'loudness': -5.722,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.0247,
#   'instrumentalness': 0.00347,
#   'liveness': 0.26,
#   'valence': 0.816,
#   'tempo': 128.03,
#   'duration_ms': 209987,
#   'time_signature': 4,
#   'chorus_hit': 64.24515,
#   'sections': 9,
#   'target': 0},
#  {'track': 'In the Dreamlife You Need a Rubber Soul',
#   'artist': 'The Clean',
#   'uri': 'spotify:track:5HKa6wcKiCxpBDSt3sY0mk',
#   'danceability': 0.56,
#   'energy': 0.808,
#   'key': 10,
#   'loudness': -6.725,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.2,
#   'instrumentalness': 0.308,
#   'liveness': 0.416,
#   'valence': 0.691,
#   'tempo': 128.051,
#   'duration_ms': 205827,
#   'time_signature': 4,
#   'chorus_hit': 30.93391,
#   'sections': 11,
#   'target': 0},
#  {'track': 'He Gets That From Me',
#   'artist': 'Reba McEntire',
#   'uri': 'spotify:track:46a3BjDPBdi6OngVhTkuM6',
#   'danceability': 0.643,
#   'energy': 0.391,
#   'key': 10,
#   'loudness': -10.09,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.622,
#   'instrumentalness': 1.38e-05,
#   'liveness': 0.11,
#   'valence': 0.418,
#   'tempo': 143.786,
#   'duration_ms': 219933,
#   'time_signature': 4,
#   'chorus_hit': 28.43124,
#   'sections': 12,
#   'target': 1},
#  {'track': 'Stay - 2006 Remaster',
#   'artist': 'Frankie Valli & The Four Seasons',
#   'uri': 'spotify:track:4T8LdAE3UU0mWIzrB9gnIg',
#   'danceability': 0.735,
#   'energy': 0.732,
#   'key': 10,
#   'loudness': -8.915,
#   'mode': 1,
#   'speechiness': 0.0699,
#   'acousticness': 0.572,
#   'instrumentalness': 2.61e-05,
#   'liveness': 0.0997,
#   'valence': 0.656,
#   'tempo': 117.58,
#   'duration_ms': 116507,
#   'time_signature': 4,
#   'chorus_hit': 45.59357,
#   'sections': 5,
#   'target': 0},
#  {'track': 'Improvisation 5',
#   'artist': 'Joe Mcphee',
#   'uri': 'spotify:track:5H1K7aT6Ox3rDBygoqVpNo',
#   'danceability': 0.536,
#   'energy': 0.081,
#   'key': 8,
#   'loudness': -20.968,
#   'mode': 1,
#   'speechiness': 0.0877,
#   'acousticness': 0.958,
#   'instrumentalness': 0.922,
#   'liveness': 0.113,
#   'valence': 0.477,
#   'tempo': 138.498,
#   'duration_ms': 186973,
#   'time_signature': 1,
#   'chorus_hit': 27.01863,
#   'sections': 8,
#   'target': 0},
#  {'track': 'Carlene',
#   'artist': 'Phil Vassar',
#   'uri': 'spotify:track:339hc1FygD8oJl4kg24IjG',
#   'danceability': 0.587,
#   'energy': 0.88,
#   'key': 4,
#   'loudness': -5.725,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.0784,
#   'instrumentalness': 0.0,
#   'liveness': 0.182,
#   'valence': 0.778,
#   'tempo': 129.222,
#   'duration_ms': 246240,
#   'time_signature': 4,
#   'chorus_hit': 20.93198,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Someday',
#   'artist': 'Sugar Ray',
#   'uri': 'spotify:track:6NcHJ23mLQKnVxQcOmT7JW',
#   'danceability': 0.743,
#   'energy': 0.67,
#   'key': 1,
#   'loudness': -4.547,
#   'mode': 0,
#   'speechiness': 0.0293,
#   'acousticness': 0.0108,
#   'instrumentalness': 0.0702,
#   'liveness': 0.22,
#   'valence': 0.934,
#   'tempo': 110.832,
#   'duration_ms': 243333,
#   'time_signature': 4,
#   'chorus_hit': 25.36994,
#   'sections': 12,
#   'target': 1},
#  {'track': '7 Days',
#   'artist': 'Craig David',
#   'uri': 'spotify:track:0gPQTLaqHDgdupKEok7J2x',
#   'danceability': 0.659,
#   'energy': 0.812,
#   'key': 4,
#   'loudness': -7.499,
#   'mode': 0,
#   'speechiness': 0.0487,
#   'acousticness': 0.23,
#   'instrumentalness': 0.0,
#   'liveness': 0.0951,
#   'valence': 0.888,
#   'tempo': 83.013,
#   'duration_ms': 235133,
#   'time_signature': 4,
#   'chorus_hit': 25.46132,
#   'sections': 12,
#   'target': 1},
#  {'track': 'True Rebel',
#   'artist': 'Nitrogenetics',
#   'uri': 'spotify:track:4atXnrsTrNuKSi7DMU5wdY',
#   'danceability': 0.539,
#   'energy': 0.985,
#   'key': 1,
#   'loudness': -7.354,
#   'mode': 1,
#   'speechiness': 0.126,
#   'acousticness': 0.00857,
#   'instrumentalness': 0.12,
#   'liveness': 0.0792,
#   'valence': 0.127,
#   'tempo': 162.065,
#   'duration_ms': 363000,
#   'time_signature': 4,
#   'chorus_hit': 25.11119,
#   'sections': 17,
#   'target': 0},
#  {'track': 'Rock Your Body',
#   'artist': 'Justin Timberlake',
#   'uri': 'spotify:track:1AWQoqb9bSvzTjaLralEkT',
#   'danceability': 0.891,
#   'energy': 0.714,
#   'key': 4,
#   'loudness': -6.055,
#   'mode': 0,
#   'speechiness': 0.14,
#   'acousticness': 0.202,
#   'instrumentalness': 0.000234,
#   'liveness': 0.0521,
#   'valence': 0.818,
#   'tempo': 100.972,
#   'duration_ms': 267267,
#   'time_signature': 4,
#   'chorus_hit': 37.11249,
#   'sections': 12,
#   'target': 1},
#  {'track': 'Bed',
#   'artist': 'J. Holiday',
#   'uri': 'spotify:track:6TlRNJaezOdzdECnQeRuMM',
#   'danceability': 0.684,
#   'energy': 0.606,
#   'key': 5,
#   'loudness': -7.268,
#   'mode': 0,
#   'speechiness': 0.0504,
#   'acousticness': 0.17,
#   'instrumentalness': 0.0,
#   'liveness': 0.058,
#   'valence': 0.723,
#   'tempo': 127.901,
#   'duration_ms': 275107,
#   'time_signature': 4,
#   'chorus_hit': 41.49527,
#   'sections': 13,
#   'target': 1},
#  {'track': 'Daft Punk Is Playing at My House - Soulwax Shibuya Mix',
#   'artist': 'LCD Soundsystem',
#   'uri': 'spotify:track:7d7l6Qnbnqv9nkuHrh6p1N',
#   'danceability': 0.658,
#   'energy': 0.954,
#   'key': 9,
#   'loudness': -5.376,
#   'mode': 1,
#   'speechiness': 0.0792,
#   'acousticness': 0.000891,
#   'instrumentalness': 9.8e-06,
#   'liveness': 0.115,
#   'valence': 0.486,
#   'tempo': 132.029,
#   'duration_ms': 411084,
#   'time_signature': 3,
#   'chorus_hit': 37.91539,
#   'sections': 18,
#   'target': 0},
#  {'track': 'Scars',
#   'artist': 'Papa Roach',
#   'uri': 'spotify:track:1UREw2MCfU0xwBzCAjxlUD',
#   'danceability': 0.471,
#   'energy': 0.936,
#   'key': 11,
#   'loudness': -3.354,
#   'mode': 1,
#   'speechiness': 0.0448,
#   'acousticness': 0.0783,
#   'instrumentalness': 0.0,
#   'liveness': 0.171,
#   'valence': 0.45,
#   'tempo': 89.881,
#   'duration_ms': 208186,
#   'time_signature': 4,
#   'chorus_hit': 22.21413,
#   'sections': 7,
#   'target': 1},
#  {'track': "Ain't It Funny",
#   'artist': 'Jennifer Lopez Featuring Ja Rule',
#   'uri': 'spotify:track:5ahFyKndeg1hqfmNumL3WF',
#   'danceability': 0.781,
#   'energy': 0.746,
#   'key': 8,
#   'loudness': -2.686,
#   'mode': 1,
#   'speechiness': 0.17,
#   'acousticness': 0.364,
#   'instrumentalness': 0.0,
#   'liveness': 0.098,
#   'valence': 0.786,
#   'tempo': 89.43,
#   'duration_ms': 229800,
#   'time_signature': 4,
#   'chorus_hit': 26.64298,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Sound Of Madness',
#   'artist': 'Shinedown',
#   'uri': 'spotify:track:0W9Xvd4Qx1aZPxEi94vgRY',
#   'danceability': 0.328,
#   'energy': 0.939,
#   'key': 2,
#   'loudness': -1.654,
#   'mode': 0,
#   'speechiness': 0.0423,
#   'acousticness': 4.93e-05,
#   'instrumentalness': 0.0065,
#   'liveness': 0.337,
#   'valence': 0.329,
#   'tempo': 185.971,
#   'duration_ms': 233987,
#   'time_signature': 4,
#   'chorus_hit': 78.255,
#   'sections': 7,
#   'target': 1},
#  {'track': 'Here I Am',
#   'artist': 'Rick Ross Featuring Nelly & Avery Storm',
#   'uri': 'spotify:track:67yGTWcR72BZvsrSS2dHST',
#   'danceability': 0.746,
#   'energy': 0.717,
#   'key': 10,
#   'loudness': -5.788,
#   'mode': 0,
#   'speechiness': 0.127,
#   'acousticness': 0.189,
#   'instrumentalness': 0.0,
#   'liveness': 0.0704,
#   'valence': 0.475,
#   'tempo': 109.753,
#   'duration_ms': 209547,
#   'time_signature': 4,
#   'chorus_hit': 38.40043,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Black Sails At Midnight',
#   'artist': 'Alestorm',
#   'uri': 'spotify:track:5K5lrptyRqoVYYDhADvzSM',
#   'danceability': 0.493,
#   'energy': 0.977,
#   'key': 5,
#   'loudness': -3.808,
#   'mode': 0,
#   'speechiness': 0.151,
#   'acousticness': 7.21e-06,
#   'instrumentalness': 0.00538,
#   'liveness': 0.356,
#   'valence': 0.322,
#   'tempo': 100.02,
#   'duration_ms': 210987,
#   'time_signature': 4,
#   'chorus_hit': 55.87392,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Crush',
#   'artist': 'David Archuleta',
#   'uri': 'spotify:track:4wCD0qOFNRu1Q6O3N6ycm4',
#   'danceability': 0.57,
#   'energy': 0.664,
#   'key': 0,
#   'loudness': -4.718,
#   'mode': 0,
#   'speechiness': 0.0322,
#   'acousticness': 0.00836,
#   'instrumentalness': 1.2e-05,
#   'liveness': 0.0719,
#   'valence': 0.487,
#   'tempo': 162.084,
#   'duration_ms': 213520,
#   'time_signature': 4,
#   'chorus_hit': 33.46,
#   'sections': 8,
#   'target': 1},
#  {'track': 'Caustic Disco',
#   'artist': 'Velvet Acid Christ',
#   'uri': 'spotify:track:10ZjRxNkqhgs4BKLuggiil',
#   'danceability': 0.564,
#   'energy': 0.878,
#   'key': 7,
#   'loudness': -6.835,
#   'mode': 1,
#   'speechiness': 0.0499,
#   'acousticness': 9.11e-06,
#   'instrumentalness': 0.793,
#   'liveness': 0.671,
#   'valence': 0.483,
#   'tempo': 127.046,
#   'duration_ms': 287600,
#   'time_signature': 4,
#   'chorus_hit': 50.27437,
#   'sections': 11,
#   'target': 0},
#  {'track': 'Arctic',
#   'artist': 'Valhall',
#   'uri': 'spotify:track:4c3TPYPHOgChuFnzECCZPX',
#   'danceability': 0.277,
#   'energy': 0.836,
#   'key': 2,
#   'loudness': -6.563,
#   'mode': 1,
#   'speechiness': 0.0458,
#   'acousticness': 0.000225,
#   'instrumentalness': 0.0284,
#   'liveness': 0.117,
#   'valence': 0.351,
#   'tempo': 95.514,
#   'duration_ms': 267128,
#   'time_signature': 4,
#   'chorus_hit': 23.12976,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Some Beach',
#   'artist': 'Blake Shelton',
#   'uri': 'spotify:track:7kWeSMXLxUHHOkFxsS0vhP',
#   'danceability': 0.787,
#   'energy': 0.765,
#   'key': 0,
#   'loudness': -6.331,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.231,
#   'instrumentalness': 1.79e-05,
#   'liveness': 0.323,
#   'valence': 0.964,
#   'tempo': 115.979,
#   'duration_ms': 204827,
#   'time_signature': 4,
#   'chorus_hit': 30.21304,
#   'sections': 10,
#   'target': 1},
#  {'track': 'When You Lie Next To Me',
#   'artist': 'Kellie Coffey',
#   'uri': 'spotify:track:6EwbFB8T0uIaaRCNwAIrnS',
#   'danceability': 0.312,
#   'energy': 0.404,
#   'key': 5,
#   'loudness': -10.014,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'acousticness': 0.184,
#   'instrumentalness': 0.0,
#   'liveness': 0.306,
#   'valence': 0.115,
#   'tempo': 138.425,
#   'duration_ms': 239827,
#   'time_signature': 4,
#   'chorus_hit': 54.21894,
#   'sections': 12,
#   'target': 1},
#  {'track': '1, 2, 3, 4',
#   'artist': "Plain White T's",
#   'uri': 'spotify:track:5VWmMZCfJ4yVkJw9ZLFXej',
#   'danceability': 0.458,
#   'energy': 0.55,
#   'key': 2,
#   'loudness': -7.092,
#   'mode': 1,
#   'speechiness': 0.0262,
#   'acousticness': 0.566,
#   'instrumentalness': 1.39e-05,
#   'liveness': 0.108,
#   'valence': 0.56,
#   'tempo': 90.56,
#   'duration_ms': 198360,
#   'time_signature': 4,
#   'chorus_hit': 22.42462,
#   'sections': 10,
#   'target': 1},
#  {'track': "Mama's Song",
#   'artist': 'Carrie Underwood',
#   'uri': 'spotify:track:0m8Ta268d1kBBG7lxMyWqa',
#   'danceability': 0.341,
#   'energy': 0.659,
#   'key': 2,
#   'loudness': -5.419,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.442,
#   'instrumentalness': 0.0,
#   'liveness': 0.096,
#   'valence': 0.269,
#   'tempo': 79.987,
#   'duration_ms': 240240,
#   'time_signature': 4,
#   'chorus_hit': 25.29826,
#   'sections': 14,
#   'target': 1},
#  {'track': 'Occult Glider',
#   'artist': 'Jazkamer',
#   'uri': 'spotify:track:2Q4VI3YbXvqzq22dWmPkp8',
#   'danceability': 0.168,
#   'energy': 0.808,
#   'key': 7,
#   'loudness': -4.563,
#   'mode': 0,
#   'speechiness': 0.108,
#   'acousticness': 0.0329,
#   'instrumentalness': 0.964,
#   'liveness': 0.331,
#   'valence': 0.0209,
#   'tempo': 91.269,
#   'duration_ms': 745600,
#   'time_signature': 3,
#   'chorus_hit': 76.55211,
#   'sections': 28,
#   'target': 0},
#  {'track': 'Hotarunohikari',
#   'artist': 'Ikimonogakari',
#   'uri': 'spotify:track:7HAkrW8JUYoVR9dXwb6Uku',
#   'danceability': 0.566,
#   'energy': 0.919,
#   'key': 2,
#   'loudness': -1.901,
#   'mode': 0,
#   'speechiness': 0.0639,
#   'acousticness': 0.0666,
#   'instrumentalness': 0.0,
#   'liveness': 0.34,
#   'valence': 0.55,
#   'tempo': 146.99,
#   'duration_ms': 242293,
#   'time_signature': 4,
#   'chorus_hit': 30.40491,
#   'sections': 11,
#   'target': 0},
#  {'track': 'Used To Love U',
#   'artist': 'John Legend',
#   'uri': 'spotify:track:051NZ3rr3HXTULCEySJRX3',
#   'danceability': 0.661,
#   'energy': 0.796,
#   'key': 7,
#   'loudness': -4.776,
#   'mode': 1,
#   'speechiness': 0.0833,
#   'acousticness': 0.0347,
#   'instrumentalness': 0.0,
#   'liveness': 0.396,
#   'valence': 0.657,
#   'tempo': 87.982,
#   'duration_ms': 210867,
#   'time_signature': 4,
#   'chorus_hit': 25.31054,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Rush',
#   'artist': 'Aly & AJ',
#   'uri': 'spotify:track:1dpXikU9kSyxm1mKulwHws',
#   'danceability': 0.548,
#   'energy': 0.815,
#   'key': 2,
#   'loudness': -5.218,
#   'mode': 0,
#   'speechiness': 0.0409,
#   'acousticness': 0.0175,
#   'instrumentalness': 8.9e-06,
#   'liveness': 0.127,
#   'valence': 0.212,
#   'tempo': 129.963,
#   'duration_ms': 191733,
#   'time_signature': 4,
#   'chorus_hit': 42.49121,
#   'sections': 8,
#   'target': 1},
#  {'track': 'I Remember',
#   'artist': 'Keyshia Cole',
#   'uri': 'spotify:track:1dObJGQUgJ7tWxJ0byON6W',
#   'danceability': 0.422,
#   'energy': 0.736,
#   'key': 5,
#   'loudness': -4.426,
#   'mode': 0,
#   'speechiness': 0.049,
#   'acousticness': 0.203,
#   'instrumentalness': 0.0,
#   'liveness': 0.102,
#   'valence': 0.303,
#   'tempo': 129.278,
#   'duration_ms': 260093,
#   'time_signature': 4,
#   'chorus_hit': 29.05424,
#   'sections': 12,
#   'target': 1},
#  {'track': 'Feeling Good - No Apologize Radio Edit',
#   'artist': 'DJ Wag',
#   'uri': 'spotify:track:0wuMFLlxogpv7clNUG9KmW',
#   'danceability': 0.71,
#   'energy': 0.796,
#   'key': 0,
#   'loudness': -9.427,
#   'mode': 1,
#   'speechiness': 0.0554,
#   'acousticness': 0.00875,
#   'instrumentalness': 0.859,
#   'liveness': 0.101,
#   'valence': 0.523,
#   'tempo': 135.012,
#   'duration_ms': 239964,
#   'time_signature': 4,
#   'chorus_hit': 18.22517,
#   'sections': 14,
#   'target': 0},
#  {'track': 'We Made It',
#   'artist': 'Busta Rhymes Featuring Linkin Park',
#   'uri': 'spotify:track:26jVcJqG66nj36jRqPBp2U',
#   'danceability': 0.62,
#   'energy': 0.746,
#   'key': 11,
#   'loudness': -6.006,
#   'mode': 1,
#   'speechiness': 0.0552,
#   'acousticness': 0.424,
#   'instrumentalness': 0.0,
#   'liveness': 0.0684,
#   'valence': 0.191,
#   'tempo': 138.454,
#   'duration_ms': 238067,
#   'time_signature': 4,
#   'chorus_hit': 23.56907,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Almost Home',
#   'artist': 'Craig Morgan',
#   'uri': 'spotify:track:6FW9MTGMjR5A6q2o7PLuuz',
#   'danceability': 0.525,
#   'energy': 0.481,
#   'key': 8,
#   'loudness': -6.715,
#   'mode': 1,
#   'speechiness': 0.0251,
#   'acousticness': 0.302,
#   'instrumentalness': 0.0,
#   'liveness': 0.121,
#   'valence': 0.237,
#   'tempo': 75.974,
#   'duration_ms': 289000,
#   'time_signature': 4,
#   'chorus_hit': 42.11222,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Who Let The Dogs Out',
#   'artist': 'Baha Men',
#   'uri': 'spotify:track:1H5tvpoApNDxvxDexoaAUo',
#   'danceability': 0.869,
#   'energy': 0.887,
#   'key': 0,
#   'loudness': -4.505,
#   'mode': 1,
#   'speechiness': 0.0993,
#   'acousticness': 0.0605,
#   'instrumentalness': 0.0,
#   'liveness': 0.148,
#   'valence': 0.784,
#   'tempo': 129.221,
#   'duration_ms': 198400,
#   'time_signature': 4,
#   'chorus_hit': 29.40143,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Pollution Rock',
#   'artist': 'Nordre Sving',
#   'uri': 'spotify:track:0nDQHCFVIZSudI5KigcO8z',
#   'danceability': 0.547,
#   'energy': 0.683,
#   'key': 2,
#   'loudness': -7.749,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.0236,
#   'instrumentalness': 0.0,
#   'liveness': 0.093,
#   'valence': 0.888,
#   'tempo': 94.937,
#   'duration_ms': 163997,
#   'time_signature': 4,
#   'chorus_hit': 48.12128,
#   'sections': 8,
#   'target': 0},
#  {'track': 'Ordinary People',
#   'artist': 'John Legend',
#   'uri': 'spotify:track:2ZA4uMlSZjaoWGFqP1tsLI',
#   'danceability': 0.469,
#   'energy': 0.132,
#   'key': 10,
#   'loudness': -14.001,
#   'mode': 1,
#   'speechiness': 0.0807,
#   'acousticness': 0.929,
#   'instrumentalness': 0.0,
#   'liveness': 0.0873,
#   'valence': 0.36,
#   'tempo': 67.011,
#   'duration_ms': 281467,
#   'time_signature': 3,
#   'chorus_hit': 23.73524,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Coming Back Around - Domu Re-Beat Mix',
#   'artist': 'Domu',
#   'uri': 'spotify:track:3ux9LeNRAgENFLcI7ZFebb',
#   'danceability': 0.364,
#   'energy': 0.866,
#   'key': 1,
#   'loudness': -6.798,
#   'mode': 1,
#   'speechiness': 0.139,
#   'acousticness': 0.0134,
#   'instrumentalness': 0.00618,
#   'liveness': 0.109,
#   'valence': 0.963,
#   'tempo': 189.091,
#   'duration_ms': 374773,
#   'time_signature': 3,
#   'chorus_hit': 29.83122,
#   'sections': 19,
#   'target': 0},
#  {'track': 'Living In Fast Forward',
#   'artist': 'Kenny Chesney',
#   'uri': 'spotify:track:0cE0J96KeivafL6goJwpmq',
#   'danceability': 0.689,
#   'energy': 0.907,
#   'key': 9,
#   'loudness': -5.587,
#   'mode': 1,
#   'speechiness': 0.037,
#   'acousticness': 0.0254,
#   'instrumentalness': 0.000732,
#   'liveness': 0.138,
#   'valence': 0.912,
#   'tempo': 116.968,
#   'duration_ms': 211893,
#   'time_signature': 4,
#   'chorus_hit': 41.28787,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Königin',
#   'artist': 'Faun',
#   'uri': 'spotify:track:5ZaquedAbEd7VAJfe0FLhE',
#   'danceability': 0.602,
#   'energy': 0.328,
#   'key': 3,
#   'loudness': -16.128,
#   'mode': 1,
#   'speechiness': 0.0249,
#   'acousticness': 0.842,
#   'instrumentalness': 0.000758,
#   'liveness': 0.208,
#   'valence': 0.413,
#   'tempo': 108.003,
#   'duration_ms': 385253,
#   'time_signature': 4,
#   'chorus_hit': 43.01027,
#   'sections': 21,
#   'target': 0},
#  {'track': 'How Far',
#   'artist': 'Martina McBride',
#   'uri': 'spotify:track:45wdPEiLuyv4oSwWQOX93R',
#   'danceability': 0.473,
#   'energy': 0.59,
#   'key': 6,
#   'loudness': -5.373,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.359,
#   'instrumentalness': 0.0,
#   'liveness': 0.101,
#   'valence': 0.334,
#   'tempo': 140.191,
#   'duration_ms': 235307,
#   'time_signature': 4,
#   'chorus_hit': 38.45284,
#   'sections': 10,
#   'target': 1},
#  {'track': '5 Star',
#   'artist': 'Yo Gotti',
#   'uri': 'spotify:track:6N9wsG0HYEpGEr0Ihgbz5r',
#   'danceability': 0.715,
#   'energy': 0.809,
#   'key': 9,
#   'loudness': -5.598,
#   'mode': 1,
#   'speechiness': 0.205,
#   'acousticness': 0.0607,
#   'instrumentalness': 0.0,
#   'liveness': 0.352,
#   'valence': 0.636,
#   'tempo': 76.493,
#   'duration_ms': 247440,
#   'time_signature': 4,
#   'chorus_hit': 29.85259,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Luckiest Man',
#   'artist': 'The Wood Brothers',
#   'uri': 'spotify:track:26uHwSHlaK5mskSMhbRod3',
#   'danceability': 0.571,
#   'energy': 0.281,
#   'key': 5,
#   'loudness': -10.56,
#   'mode': 1,
#   'speechiness': 0.0475,
#   'acousticness': 0.74,
#   'instrumentalness': 0.0,
#   'liveness': 0.163,
#   'valence': 0.294,
#   'tempo': 142.263,
#   'duration_ms': 233667,
#   'time_signature': 4,
#   'chorus_hit': 42.29581,
#   'sections': 9,
#   'target': 0},
#  {'track': 'Blow Me',
#   'artist': 'DJ D',
#   'uri': 'spotify:track:2ohXvQLyB5RbZ0du4fAQHX',
#   'danceability': 0.461,
#   'energy': 0.93,
#   'key': 8,
#   'loudness': -8.343,
#   'mode': 0,
#   'speechiness': 0.187,
#   'acousticness': 0.0531,
#   'instrumentalness': 0.733,
#   'liveness': 0.177,
#   'valence': 0.14,
#   'tempo': 163.934,
#   'duration_ms': 371984,
#   'time_signature': 4,
#   'chorus_hit': 48.20956,
#   'sections': 19,
#   'target': 0},
#  {'track': 'Still Broken',
#   'artist': 'Plan Three',
#   'uri': 'spotify:track:2ajt6aQwvgu2eJbNIZhJFY',
#   'danceability': 0.51,
#   'energy': 0.881,
#   'key': 11,
#   'loudness': -4.384,
#   'mode': 0,
#   'speechiness': 0.0354,
#   'acousticness': 0.000591,
#   'instrumentalness': 1.46e-05,
#   'liveness': 0.131,
#   'valence': 0.278,
#   'tempo': 91.034,
#   'duration_ms': 232093,
#   'time_signature': 4,
#   'chorus_hit': 31.97236,
#   'sections': 9,
#   'target': 0},
#  {'track': "Life Ain't Always Beautiful",
#   'artist': 'Gary Allan',
#   'uri': 'spotify:track:3unLUM6bJcy5beGawHpynM',
#   'danceability': 0.481,
#   'energy': 0.508,
#   'key': 2,
#   'loudness': -7.666,
#   'mode': 1,
#   'speechiness': 0.0248,
#   'acousticness': 0.216,
#   'instrumentalness': 0.000175,
#   'liveness': 0.105,
#   'valence': 0.268,
#   'tempo': 86.013,
#   'duration_ms': 224613,
#   'time_signature': 4,
#   'chorus_hit': 71.34437,
#   'sections': 7,
#   'target': 1},
#  {'track': 'Kiss A Girl',
#   'artist': 'Keith Urban',
#   'uri': 'spotify:track:4DyKZmONpoggnn3piyjad2',
#   'danceability': 0.653,
#   'energy': 0.786,
#   'key': 2,
#   'loudness': -5.418,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.0103,
#   'instrumentalness': 2.19e-06,
#   'liveness': 0.201,
#   'valence': 0.477,
#   'tempo': 120.992,
#   'duration_ms': 226733,
#   'time_signature': 4,
#   'chorus_hit': 33.55326,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Open House',
#   'artist': 'Guru',
#   'uri': 'spotify:track:2nIQLI6m0qgjuZ6eO3f7r3',
#   'danceability': 0.744,
#   'energy': 0.739,
#   'key': 4,
#   'loudness': -6.272,
#   'mode': 0,
#   'speechiness': 0.307,
#   'acousticness': 0.119,
#   'instrumentalness': 0.0,
#   'liveness': 0.106,
#   'valence': 0.678,
#   'tempo': 79.245,
#   'duration_ms': 185582,
#   'time_signature': 4,
#   'chorus_hit': 28.99861,
#   'sections': 8,
#   'target': 0},
#  {'track': '1000 Estrellas',
#   'artist': 'Charlie 3',
#   'uri': 'spotify:track:4dk59nVJKBJCPupuL6RGae',
#   'danceability': 0.473,
#   'energy': 0.722,
#   'key': 5,
#   'loudness': -5.176,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.00507,
#   'instrumentalness': 0.0,
#   'liveness': 0.377,
#   'valence': 0.549,
#   'tempo': 149.625,
#   'duration_ms': 256000,
#   'time_signature': 4,
#   'chorus_hit': 40.17949,
#   'sections': 11,
#   'target': 0},
#  {'track': 'Another Postcard (Chimps)',
#   'artist': 'Barenaked Ladies',
#   'uri': 'spotify:track:6rMx1neL9mLYivQ5U6PFk3',
#   'danceability': 0.621,
#   'energy': 0.747,
#   'key': 1,
#   'loudness': -6.552,
#   'mode': 0,
#   'speechiness': 0.0782,
#   'acousticness': 0.00227,
#   'instrumentalness': 0.000234,
#   'liveness': 0.0449,
#   'valence': 0.726,
#   'tempo': 172.31,
#   'duration_ms': 205267,
#   'time_signature': 4,
#   'chorus_hit': 63.6742,
#   'sections': 8,
#   'target': 1},
#  {'track': 'As Good As I Once Was',
#   'artist': 'Toby Keith',
#   'uri': 'spotify:track:7G6l2FtQyRhQgYgut2I6i8',
#   'danceability': 0.68,
#   'energy': 0.87,
#   'key': 5,
#   'loudness': -4.461,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.266,
#   'instrumentalness': 0.0,
#   'liveness': 0.109,
#   'valence': 0.646,
#   'tempo': 119.075,
#   'duration_ms': 227840,
#   'time_signature': 4,
#   'chorus_hit': 57.79785,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Headsprung',
#   'artist': 'LL Cool J',
#   'uri': 'spotify:track:1GIN41bLhiKeEPeC2vXH8i',
#   'danceability': 0.718,
#   'energy': 0.786,
#   'key': 0,
#   'loudness': -5.76,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.0114,
#   'instrumentalness': 2.5e-05,
#   'liveness': 0.0745,
#   'valence': 0.465,
#   'tempo': 99.916,
#   'duration_ms': 267320,
#   'time_signature': 4,
#   'chorus_hit': 40.33202,
#   'sections': 20,
#   'target': 1},
#  {'track': 'Polonaise Brilliante',
#   'artist': 'Nikolai Kapustin',
#   'uri': 'spotify:track:3sO3HX4EP1jS9rZW9OvHCN',
#   'danceability': 0.387,
#   'energy': 0.268,
#   'key': 0,
#   'loudness': -13.996,
#   'mode': 1,
#   'speechiness': 0.0348,
#   'acousticness': 0.995,
#   'instrumentalness': 0.828,
#   'liveness': 0.0942,
#   'valence': 0.337,
#   'tempo': 113.357,
#   'duration_ms': 518227,
#   'time_signature': 4,
#   'chorus_hit': 28.63663,
#   'sections': 17,
#   'target': 0},
#  {'track': 'Forever Heavy',
#   'artist': 'Black Moth Super Rainbow',
#   'uri': 'spotify:track:56e8Ac9LVRJf3SvVa9vVg0',
#   'danceability': 0.384,
#   'energy': 0.735,
#   'key': 5,
#   'loudness': -4.856,
#   'mode': 0,
#   'speechiness': 0.0383,
#   'acousticness': 0.703,
#   'instrumentalness': 0.921,
#   'liveness': 0.232,
#   'valence': 0.276,
#   'tempo': 133.906,
#   'duration_ms': 256013,
#   'time_signature': 4,
#   'chorus_hit': 78.69983,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Treasure',
#   'artist': 'Trevor Rabin',
#   'uri': 'spotify:track:2X42kkAi74tp2Je6OuML6c',
#   'danceability': 0.064,
#   'energy': 0.0794,
#   'key': 3,
#   'loudness': -16.971,
#   'mode': 1,
#   'speechiness': 0.0403,
#   'acousticness': 0.432,
#   'instrumentalness': 0.896,
#   'liveness': 0.151,
#   'valence': 0.0356,
#   'tempo': 63.29,
#   'duration_ms': 218947,
#   'time_signature': 4,
#   'chorus_hit': 57.70217,
#   'sections': 12,
#   'target': 0},
#  {'track': 'L.A. Song',
#   'artist': 'Beth Hart',
#   'uri': 'spotify:track:69pBTbnLue0leYUCMAFqPj',
#   'danceability': 0.351,
#   'energy': 0.615,
#   'key': 7,
#   'loudness': -7.621,
#   'mode': 1,
#   'speechiness': 0.0451,
#   'acousticness': 0.206,
#   'instrumentalness': 0.0,
#   'liveness': 0.985,
#   'valence': 0.337,
#   'tempo': 127.798,
#   'duration_ms': 271107,
#   'time_signature': 3,
#   'chorus_hit': 58.57055,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Chicks Dig It',
#   'artist': 'Chris Cagle',
#   'uri': 'spotify:track:0nprj2O0teCglthuhzTG5o',
#   'danceability': 0.596,
#   'energy': 0.921,
#   'key': 7,
#   'loudness': -4.987,
#   'mode': 1,
#   'speechiness': 0.0504,
#   'acousticness': 0.0221,
#   'instrumentalness': 0.0,
#   'liveness': 0.303,
#   'valence': 0.703,
#   'tempo': 104.024,
#   'duration_ms': 210560,
#   'time_signature': 4,
#   'chorus_hit': 29.07478,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Nin-com-pop - Two Lone Swordsmen - Sampler Version',
#   'artist': 'Lali Puna',
#   'uri': 'spotify:track:6VVvxfr9thHNyd61X0FNAV',
#   'danceability': 0.726,
#   'energy': 0.294,
#   'key': 4,
#   'loudness': -14.451,
#   'mode': 0,
#   'speechiness': 0.0472,
#   'acousticness': 0.595,
#   'instrumentalness': 0.717,
#   'liveness': 0.0385,
#   'valence': 0.185,
#   'tempo': 125.712,
#   'duration_ms': 206733,
#   'time_signature': 4,
#   'chorus_hit': 29.71117,
#   'sections': 12,
#   'target': 0},
#  {'track': 'I Wanna Be Your Dog',
#   'artist': 'Sky Saxon',
#   'uri': 'spotify:track:1jEOVktr2HSpay9i6pqWBG',
#   'danceability': 0.598,
#   'energy': 0.782,
#   'key': 4,
#   'loudness': -6.018,
#   'mode': 1,
#   'speechiness': 0.0305,
#   'acousticness': 0.407,
#   'instrumentalness': 6.55e-05,
#   'liveness': 0.558,
#   'valence': 0.298,
#   'tempo': 118.938,
#   'duration_ms': 205053,
#   'time_signature': 4,
#   'chorus_hit': 21.29442,
#   'sections': 10,
#   'target': 0},
#  {'track': "What's Left Of Me",
#   'artist': 'Nick Lachey',
#   'uri': 'spotify:track:1bPqAXwNiVcM6zjJU1Z4Cd',
#   'danceability': 0.421,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -5.644,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.136,
#   'instrumentalness': 0.0,
#   'liveness': 0.136,
#   'valence': 0.311,
#   'tempo': 150.12,
#   'duration_ms': 244667,
#   'time_signature': 4,
#   'chorus_hit': 29.22179,
#   'sections': 11,
#   'target': 1},
#  {'track': 'I Learned From The Best',
#   'artist': 'Whitney Houston',
#   'uri': 'spotify:track:3wACjmQo7ZkRNMLfZXndFB',
#   'danceability': 0.609,
#   'energy': 0.563,
#   'key': 5,
#   'loudness': -6.284,
#   'mode': 0,
#   'speechiness': 0.0328,
#   'acousticness': 0.0109,
#   'instrumentalness': 7.76e-06,
#   'liveness': 0.156,
#   'valence': 0.306,
#   'tempo': 148.949,
#   'duration_ms': 259533,
#   'time_signature': 4,
#   'chorus_hit': 41.68325,
#   'sections': 14,
#   'target': 1},
#  {'track': 'Broken',
#   'artist': 'Seether Featuring Amy Lee',
#   'uri': 'spotify:track:507bYMYfbm6sUS9iEAaeSd',
#   'danceability': 0.448,
#   'energy': 0.61,
#   'key': 3,
#   'loudness': -2.695,
#   'mode': 0,
#   'speechiness': 0.0342,
#   'acousticness': 0.0102,
#   'instrumentalness': 0.000491,
#   'liveness': 0.135,
#   'valence': 0.214,
#   'tempo': 123.762,
#   'duration_ms': 258333,
#   'time_signature': 4,
#   'chorus_hit': 48.88537,
#   'sections': 12,
#   'target': 1},
#  {'track': "I'd Do Anything",
#   'artist': 'Simple Plan',
#   'uri': 'spotify:track:4uVjbl6daCwjhDur7qLddu',
#   'danceability': 0.395,
#   'energy': 0.917,
#   'key': 8,
#   'loudness': -6.86,
#   'mode': 1,
#   'speechiness': 0.133,
#   'acousticness': 0.00143,
#   'instrumentalness': 0.0,
#   'liveness': 0.261,
#   'valence': 0.563,
#   'tempo': 169.088,
#   'duration_ms': 197640,
#   'time_signature': 4,
#   'chorus_hit': 30.63383,
#   'sections': 6,
#   'target': 1},
#  {'track': 'Sleepy Silver Door',
#   'artist': 'Dead Meadow',
#   'uri': 'spotify:track:2HlBvuaKhdftTRb3TCklhQ',
#   'danceability': 0.365,
#   'energy': 0.632,
#   'key': 11,
#   'loudness': -6.574,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.444,
#   'instrumentalness': 0.708,
#   'liveness': 0.127,
#   'valence': 0.289,
#   'tempo': 129.545,
#   'duration_ms': 452747,
#   'time_signature': 4,
#   'chorus_hit': 43.87393,
#   'sections': 15,
#   'target': 0},
#  {'track': 'People Make The World Go Round (Boris Main Mix)',
#   'artist': 'Joi Cardwell',
#   'uri': 'spotify:track:6UhrIkR4sDh8LpoWdUVzt1',
#   'danceability': 0.792,
#   'energy': 0.637,
#   'key': 4,
#   'loudness': -9.826,
#   'mode': 0,
#   'speechiness': 0.0743,
#   'acousticness': 0.000443,
#   'instrumentalness': 0.448,
#   'liveness': 0.0698,
#   'valence': 0.366,
#   'tempo': 127.989,
#   'duration_ms': 481350,
#   'time_signature': 4,
#   'chorus_hit': 57.90045,
#   'sections': 18,
#   'target': 0},
#  {'track': 'God Is Dead',
#   'artist': 'Heart Attack',
#   'uri': 'spotify:track:0k3akiXIyGFLT31IC3twkP',
#   'danceability': 0.343,
#   'energy': 0.972,
#   'key': 1,
#   'loudness': -9.573,
#   'mode': 0,
#   'speechiness': 0.079,
#   'acousticness': 1.52e-06,
#   'instrumentalness': 0.51,
#   'liveness': 0.0501,
#   'valence': 0.547,
#   'tempo': 94.927,
#   'duration_ms': 82187,
#   'time_signature': 4,
#   'chorus_hit': 14.98454,
#   'sections': 3,
#   'target': 0},
#  {'track': 'Meet Me Halfway',
#   'artist': 'The Black Eyed Peas',
#   'uri': 'spotify:track:0xfpx7AiwgSKEtjotea2L6',
#   'danceability': 0.798,
#   'energy': 0.629,
#   'key': 11,
#   'loudness': -6.857,
#   'mode': 0,
#   'speechiness': 0.0735,
#   'acousticness': 0.00474,
#   'instrumentalness': 2.17e-05,
#   'liveness': 0.324,
#   'valence': 0.4,
#   'tempo': 130.0,
#   'duration_ms': 284373,
#   'time_signature': 4,
#   'chorus_hit': 30.48537,
#   'sections': 14,
#   'target': 1},
#  {'track': 'Deathmask Divine',
#   'artist': 'The Black Dahlia Murder',
#   'uri': 'spotify:track:3oCTRjyXmT1MMn4nVQMKBm',
#   'danceability': 0.471,
#   'energy': 0.993,
#   'key': 1,
#   'loudness': -3.738,
#   'mode': 1,
#   'speechiness': 0.191,
#   'acousticness': 7.36e-06,
#   'instrumentalness': 0.00216,
#   'liveness': 0.0925,
#   'valence': 0.0672,
#   'tempo': 113.996,
#   'duration_ms': 217253,
#   'time_signature': 4,
#   'chorus_hit': 18.99449,
#   'sections': 12,
#   'target': 0},
#  {'track': 'Step Daddy',
#   'artist': 'Hitman Sammy Sam',
#   'uri': 'spotify:track:1TKRumlRMXv2SEKPhueya0',
#   'danceability': 0.93,
#   'energy': 0.773,
#   'key': 1,
#   'loudness': -5.98,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'acousticness': 0.00609,
#   'instrumentalness': 0.000481,
#   'liveness': 0.0767,
#   'valence': 0.348,
#   'tempo': 118.997,
#   'duration_ms': 230493,
#   'time_signature': 4,
#   'chorus_hit': 31.99187,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Rock and Roll Marionett',
#   'artist': 'Stein Ingebrigtsen',
#   'uri': 'spotify:track:1VOPQGI9tO0S1SKSoOqAiC',
#   'danceability': 0.682,
#   'energy': 0.579,
#   'key': 7,
#   'loudness': -7.924,
#   'mode': 1,
#   'speechiness': 0.0712,
#   'acousticness': 0.196,
#   'instrumentalness': 0.0,
#   'liveness': 0.136,
#   'valence': 0.784,
#   'tempo': 100.186,
#   'duration_ms': 222589,
#   'time_signature': 4,
#   'chorus_hit': 43.76046,
#   'sections': 8,
#   'target': 0},
#  {'track': 'I Miss You',
#   'artist': 'Blink-182',
#   'uri': 'spotify:track:1oTo3ijRbaDAtrjJrGAPSw',
#   'danceability': 0.664,
#   'energy': 0.781,
#   'key': 11,
#   'loudness': -6.547,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.00103,
#   'instrumentalness': 5.33e-06,
#   'liveness': 0.0867,
#   'valence': 0.593,
#   'tempo': 110.0,
#   'duration_ms': 227240,
#   'time_signature': 4,
#   'chorus_hit': 30.64844,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Gråt inga tårar mer',
#   'artist': 'Titanix',
#   'uri': 'spotify:track:3M9rd6Ypxn783h5Y5HLNjF',
#   'danceability': 0.59,
#   'energy': 0.836,
#   'key': 7,
#   'loudness': -2.805,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.00334,
#   'instrumentalness': 0.0,
#   'liveness': 0.0358,
#   'valence': 0.939,
#   'tempo': 138.84,
#   'duration_ms': 143000,
#   'time_signature': 4,
#   'chorus_hit': 45.10531,
#   'sections': 6,
#   'target': 0},
#  {'track': 'The Saints Are Coming',
#   'artist': 'U2 & Green Day',
#   'uri': 'spotify:track:6uQL0epVs9N9Bergafaf6x',
#   'danceability': 0.315,
#   'energy': 0.81,
#   'key': 4,
#   'loudness': -7.026,
#   'mode': 0,
#   'speechiness': 0.0468,
#   'acousticness': 0.0781,
#   'instrumentalness': 0.00321,
#   'liveness': 0.152,
#   'valence': 0.118,
#   'tempo': 152.116,
#   'duration_ms': 201907,
#   'time_signature': 4,
#   'chorus_hit': 33.25761,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Good Luck',
#   'artist': 'Basement Jaxx',
#   'uri': 'spotify:track:2bmmeB82W3J241MijDIiHk',
#   'danceability': 0.577,
#   'energy': 0.936,
#   'key': 5,
#   'loudness': -4.179,
#   'mode': 1,
#   'speechiness': 0.0915,
#   'acousticness': 0.0839,
#   'instrumentalness': 0.0,
#   'liveness': 0.344,
#   'valence': 0.572,
#   'tempo': 153.985,
#   'duration_ms': 211547,
#   'time_signature': 4,
#   'chorus_hit': 25.54091,
#   'sections': 12,
#   'target': 0},
#  {'track': 'Beautiful',
#   'artist': 'Christina Aguilera',
#   'uri': 'spotify:track:3TCauNPqFiniaYHBvEVoHG',
#   'danceability': 0.457,
#   'energy': 0.573,
#   'key': 5,
#   'loudness': -3.866,
#   'mode': 0,
#   'speechiness': 0.0275,
#   'acousticness': 0.578,
#   'instrumentalness': 3.05e-06,
#   'liveness': 0.114,
#   'valence': 0.0992,
#   'tempo': 76.193,
#   'duration_ms': 238560,
#   'time_signature': 4,
#   'chorus_hit': 29.82293,
#   'sections': 11,
#   'target': 1},
#  {'track': 'The Orange Fox Waits',
#   'artist': 'Robin Spielberg',
#   'uri': 'spotify:track:1aTcDNvEBoqWN9FxuoBhfB',
#   'danceability': 0.441,
#   'energy': 0.0712,
#   'key': 2,
#   'loudness': -21.625,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.995,
#   'instrumentalness': 0.934,
#   'liveness': 0.0917,
#   'valence': 0.157,
#   'tempo': 94.35,
#   'duration_ms': 185533,
#   'time_signature': 4,
#   'chorus_hit': 58.47325,
#   'sections': 7,
#   'target': 0},
#  {'track': 'You Rock My World',
#   'artist': 'Java Gospel',
#   'uri': 'spotify:track:00nQhTtc8FxgmB0NWypSE0',
#   'danceability': 0.662,
#   'energy': 0.854,
#   'key': 1,
#   'loudness': -5.518,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.133,
#   'instrumentalness': 0.0,
#   'liveness': 0.333,
#   'valence': 0.915,
#   'tempo': 121.961,
#   'duration_ms': 245947,
#   'time_signature': 4,
#   'chorus_hit': 40.45327,
#   'sections': 11,
#   'target': 0},
#  {'track': 'Shadow Of The Day',
#   'artist': 'Linkin Park',
#   'uri': 'spotify:track:0OYcEfskah1egYHjYRvbg1',
#   'danceability': 0.534,
#   'energy': 0.393,
#   'key': 11,
#   'loudness': -7.813,
#   'mode': 1,
#   'speechiness': 0.0292,
#   'acousticness': 0.00479,
#   'instrumentalness': 0.0107,
#   'liveness': 0.107,
#   'valence': 0.0641,
#   'tempo': 110.007,
#   'duration_ms': 290360,
#   'time_signature': 4,
#   'chorus_hit': 58.45602,
#   'sections': 9,
#   'target': 1},
#  {'track': "99.9% Sure (I've Never Been Here Before)",
#   'artist': 'Brian McComas',
#   'uri': 'spotify:track:14ymPtb1n06KzSm0J9bmMZ',
#   'danceability': 0.606,
#   'energy': 0.959,
#   'key': 7,
#   'loudness': -3.412,
#   'mode': 1,
#   'speechiness': 0.0522,
#   'acousticness': 0.0714,
#   'instrumentalness': 0.0,
#   'liveness': 0.236,
#   'valence': 0.734,
#   'tempo': 116.014,
#   'duration_ms': 193293,
#   'time_signature': 4,
#   'chorus_hit': 59.85298,
#   'sections': 8,
#   'target': 1},
#  {'track': 'Some People Change',
#   'artist': 'Montgomery Gentry',
#   'uri': 'spotify:track:7cmZDjXMF1A0dGV726pMYs',
#   'danceability': 0.55,
#   'energy': 0.61,
#   'key': 2,
#   'loudness': -6.358,
#   'mode': 1,
#   'speechiness': 0.0388,
#   'acousticness': 0.0456,
#   'instrumentalness': 0.0,
#   'liveness': 0.11,
#   'valence': 0.357,
#   'tempo': 168.186,
#   'duration_ms': 201867,
#   'time_signature': 4,
#   'chorus_hit': 24.3249,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Right Where You Want Me',
#   'artist': 'Jesse McCartney',
#   'uri': 'spotify:track:58ZvuqZgeuZMCbpCsH9E76',
#   'danceability': 0.72,
#   'energy': 0.548,
#   'key': 4,
#   'loudness': -4.805,
#   'mode': 0,
#   'speechiness': 0.0291,
#   'acousticness': 0.00269,
#   'instrumentalness': 0.000118,
#   'liveness': 0.0511,
#   'valence': 0.709,
#   'tempo': 99.004,
#   'duration_ms': 211693,
#   'time_signature': 4,
#   'chorus_hit': 28.30516,
#   'sections': 8,
#   'target': 1},
#  {'track': "Baby It's You",
#   'artist': 'JoJo Featuring Bow Wow',
#   'uri': 'spotify:track:5TV96lkS2NF6kzILjORzLs',
#   'danceability': 0.858,
#   'energy': 0.607,
#   'key': 1,
#   'loudness': -4.199,
#   'mode': 1,
#   'speechiness': 0.118,
#   'acousticness': 0.0169,
#   'instrumentalness': 3.97e-05,
#   'liveness': 0.0777,
#   'valence': 0.821,
#   'tempo': 119.986,
#   'duration_ms': 188293,
#   'time_signature': 3,
#   'chorus_hit': 66.31259,
#   'sections': 9,
#   'target': 1},
#  {'track': "Help Pour Out The Rain (Lacey's Song)",
#   'artist': 'Buddy Jewell',
#   'uri': 'spotify:track:4xWIqUIlfrusaaygS9RQsR',
#   'danceability': 0.565,
#   'energy': 0.562,
#   'key': 0,
#   'loudness': -7.43,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.263,
#   'instrumentalness': 0.0,
#   'liveness': 0.0994,
#   'valence': 0.652,
#   'tempo': 75.035,
#   'duration_ms': 229093,
#   'time_signature': 4,
#   'chorus_hit': 25.98469,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Ever The Same',
#   'artist': 'Rob Thomas',
#   'uri': 'spotify:track:02acUMylPHMjJ9miDc9b38',
#   'danceability': 0.435,
#   'energy': 0.729,
#   'key': 1,
#   'loudness': -4.818,
#   'mode': 0,
#   'speechiness': 0.0307,
#   'acousticness': 0.0152,
#   'instrumentalness': 2.63e-05,
#   'liveness': 0.11,
#   'valence': 0.524,
#   'tempo': 188.017,
#   'duration_ms': 256600,
#   'time_signature': 4,
#   'chorus_hit': 41.42314,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Bombay Jazz',
#   'artist': 'Carlo Fashion',
#   'uri': 'spotify:track:470NlXJBatHwrcnfGFJylg',
#   'danceability': 0.65,
#   'energy': 0.72,
#   'key': 11,
#   'loudness': -8.803,
#   'mode': 1,
#   'speechiness': 0.161,
#   'acousticness': 0.0238,
#   'instrumentalness': 0.14,
#   'liveness': 0.367,
#   'valence': 0.738,
#   'tempo': 154.664,
#   'duration_ms': 170213,
#   'time_signature': 4,
#   'chorus_hit': 59.91442,
# ...
#   'acousticness': 3.52e-05,
#   'instrumentalness': 2.56e-05,
#   'liveness': 0.17,
#   'valence': 0.365,
#   'tempo': 144.035,
#   'duration_ms': 217400,
#   'time_signature': 4,
#   'chorus_hit': 20.1212,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Last Wave',
#   'artist': 'Jeff Greinke',
#   'uri': 'spotify:track:3xE2uc5Es7oGviqf65wpqt',
#   'danceability': 0.065,
#   'energy': 0.23,
#   'key': 11,
#   'loudness': -17.236,
#   'mode': 0,
#   'speechiness': 0.0442,
#   'acousticness': 0.978,
#   'instrumentalness': 0.925,
#   'liveness': 0.0955,
#   'valence': 0.0384,
#   'tempo': 62.16,
#   'duration_ms': 627013,
#   'time_signature': 4,
#   'chorus_hit': 26.8173,
#   'sections': 32,
#   'target': 0},
#  {'track': 'Hands Clean',
#   'artist': 'Alanis Morissette',
#   'uri': 'spotify:track:3NmAPSJMgKo4bqoUbO1qcB',
#   'danceability': 0.513,
#   'energy': 0.82,
#   'key': 7,
#   'loudness': -5.428,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.00192,
#   'instrumentalness': 2.83e-06,
#   'liveness': 0.504,
#   'valence': 0.52,
#   'tempo': 99.952,
#   'duration_ms': 269400,
#   'time_signature': 4,
#   'chorus_hit': 64.50208,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Psycho',
#   'artist': 'Puddle Of Mudd',
#   'uri': 'spotify:track:3e2KBwxibC1rq4bA5TNKW2',
#   'danceability': 0.573,
#   'energy': 0.897,
#   'key': 1,
#   'loudness': -3.549,
#   'mode': 1,
#   'speechiness': 0.0553,
#   'acousticness': 0.00473,
#   'instrumentalness': 0.0,
#   'liveness': 0.278,
#   'valence': 0.463,
#   'tempo': 126.034,
#   'duration_ms': 210653,
#   'time_signature': 4,
#   'chorus_hit': 25.40819,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Until We Bleed (feat. Lykke Li)',
#   'artist': 'Kleerup',
#   'uri': 'spotify:track:4R9tl76Nf4xr8GMhcpaNDm',
#   'danceability': 0.642,
#   'energy': 0.756,
#   'key': 9,
#   'loudness': -5.526,
#   'mode': 0,
#   'speechiness': 0.0617,
#   'acousticness': 0.305,
#   'instrumentalness': 0.252,
#   'liveness': 0.0825,
#   'valence': 0.525,
#   'tempo': 120.016,
#   'duration_ms': 264040,
#   'time_signature': 4,
#   'chorus_hit': 47.77681,
#   'sections': 13,
#   'target': 0},
#  {'track': 'Game Over (Flip)',
#   'artist': "Lil' Flip",
#   'uri': 'spotify:track:79lmvU7Qmc8QpXilbSk37z',
#   'danceability': 0.813,
#   'energy': 0.59,
#   'key': 8,
#   'loudness': -8.998,
#   'mode': 1,
#   'speechiness': 0.378,
#   'acousticness': 0.00106,
#   'instrumentalness': 5.07e-05,
#   'liveness': 0.0809,
#   'valence': 0.602,
#   'tempo': 159.961,
#   'duration_ms': 232467,
#   'time_signature': 4,
#   'chorus_hit': 38.94443,
#   'sections': 8,
#   'target': 1},
#  {'track': 'I Wanna Do It All',
#   'artist': 'Terri Clark',
#   'uri': 'spotify:track:56sAXFMfTagQGl5KOxvdxt',
#   'danceability': 0.626,
#   'energy': 0.886,
#   'key': 4,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.034,
#   'acousticness': 0.0668,
#   'instrumentalness': 0.0,
#   'liveness': 0.118,
#   'valence': 0.782,
#   'tempo': 132.905,
#   'duration_ms': 173333,
#   'time_signature': 4,
#   'chorus_hit': 30.81479,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Skull Creek Logger',
#   'artist': 'The Wages of Sin',
#   'uri': 'spotify:track:6ZGdCZ2kyGgEXx5PjCji2Y',
#   'danceability': 0.411,
#   'energy': 0.9,
#   'key': 0,
#   'loudness': -4.079,
#   'mode': 1,
#   'speechiness': 0.0805,
#   'acousticness': 0.0319,
#   'instrumentalness': 0.0577,
#   'liveness': 0.131,
#   'valence': 0.921,
#   'tempo': 162.003,
#   'duration_ms': 211213,
#   'time_signature': 4,
#   'chorus_hit': 57.437,
#   'sections': 7,
#   'target': 0},
#  {'track': 'Bad Attitude',
#   'artist': 'Darkthrone',
#   'uri': 'spotify:track:2a9ZwbOpnfAx1WGq6JPp14',
#   'danceability': 0.144,
#   'energy': 0.983,
#   'key': 9,
#   'loudness': -1.258,
#   'mode': 1,
#   'speechiness': 0.0914,
#   'acousticness': 0.0479,
#   'instrumentalness': 1.6e-05,
#   'liveness': 0.0361,
#   'valence': 0.577,
#   'tempo': 188.972,
#   'duration_ms': 107067,
#   'time_signature': 4,
#   'chorus_hit': 27.50289,
#   'sections': 7,
#   'target': 0},
#  {'track': 'Turn My Headphones Up',
#   'artist': 'Sinking Ships',
#   'uri': 'spotify:track:2PcO7PL7a5CGnDtT2pgXau',
#   'danceability': 0.324,
#   'energy': 0.924,
#   'key': 7,
#   'loudness': -3.349,
#   'mode': 1,
#   'speechiness': 0.114,
#   'acousticness': 3.01e-05,
#   'instrumentalness': 0.000325,
#   'liveness': 0.231,
#   'valence': 0.419,
#   'tempo': 86.456,
#   'duration_ms': 142200,
#   'time_signature': 4,
#   'chorus_hit': 78.13033,
#   'sections': 4,
#   'target': 0},
#  {'track': 'Crazy',
#   'artist': 'Gnarls Barkley',
#   'uri': 'spotify:track:2N5zMZX7YeL1tico8oQxa9',
#   'danceability': 0.835,
#   'energy': 0.741,
#   'key': 8,
#   'loudness': -1.609,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.0172,
#   'instrumentalness': 0.0577,
#   'liveness': 0.0826,
#   'valence': 0.612,
#   'tempo': 111.963,
#   'duration_ms': 182066,
#   'time_signature': 4,
#   'chorus_hit': 23.04284,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Wait A Minute',
#   'artist': "Ray J Featuring Lil' Kim",
#   'uri': 'spotify:track:7xwFOVYwBuLvFquLyfooRp',
#   'danceability': 0.89,
#   'energy': 0.701,
#   'key': 7,
#   'loudness': -4.954,
#   'mode': 1,
#   'speechiness': 0.205,
#   'acousticness': 0.0681,
#   'instrumentalness': 0.0,
#   'liveness': 0.243,
#   'valence': 0.728,
#   'tempo': 100.018,
#   'duration_ms': 227267,
#   'time_signature': 4,
#   'chorus_hit': 18.71484,
#   'sections': 9,
#   'target': 1},
#  {'track': 'All I Ever Wanted',
#   'artist': 'Chuck Wicks',
#   'uri': 'spotify:track:6RKrORavcsGPPrkRzkU14H',
#   'danceability': 0.538,
#   'energy': 0.773,
#   'key': 11,
#   'loudness': -4.659,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.0268,
#   'instrumentalness': 0.0,
#   'liveness': 0.0829,
#   'valence': 0.611,
#   'tempo': 94.053,
#   'duration_ms': 207333,
#   'time_signature': 4,
#   'chorus_hit': 18.90371,
#   'sections': 14,
#   'target': 1},
#  {'track': 'What Am I Gonna Do',
#   'artist': 'Tyrese',
#   'uri': 'spotify:track:7FFQsnjzumC6eyCXRFPQ2f',
#   'danceability': 0.69,
#   'energy': 0.475,
#   'key': 10,
#   'loudness': -4.702,
#   'mode': 0,
#   'speechiness': 0.052,
#   'acousticness': 0.275,
#   'instrumentalness': 0.0,
#   'liveness': 0.0951,
#   'valence': 0.536,
#   'tempo': 145.597,
#   'duration_ms': 280000,
#   'time_signature': 4,
#   'chorus_hit': 40.01115,
#   'sections': 17,
#   'target': 1},
#  {'track': 'Like A Pimp',
#   'artist': "David Banner Featuring Lil' Flip",
#   'uri': 'spotify:track:0DW5anNzTO7h0OlKqFsVQ6',
#   'danceability': 0.851,
#   'energy': 0.848,
#   'key': 7,
#   'loudness': -5.136,
#   'mode': 1,
#   'speechiness': 0.181,
#   'acousticness': 0.00472,
#   'instrumentalness': 0.0,
#   'liveness': 0.0783,
#   'valence': 0.897,
#   'tempo': 144.092,
#   'duration_ms': 254707,
#   'time_signature': 4,
#   'chorus_hit': 24.75047,
#   'sections': 11,
#   'target': 1},
#  {'track': "Livin' Our Love Song",
#   'artist': 'Jason Michael Carroll',
#   'uri': 'spotify:track:5NhZkLMccDVhxocmVHDu4G',
#   'danceability': 0.488,
#   'energy': 0.855,
#   'key': 7,
#   'loudness': -3.417,
#   'mode': 1,
#   'speechiness': 0.0399,
#   'acousticness': 0.287,
#   'instrumentalness': 0.0,
#   'liveness': 0.132,
#   'valence': 0.799,
#   'tempo': 148.971,
#   'duration_ms': 231467,
#   'time_signature': 4,
#   'chorus_hit': 22.76559,
#   'sections': 13,
#   'target': 1},
#  {'track': 'Gardermoen',
#   'artist': 'Julia Kent',
#   'uri': 'spotify:track:1WEGB2t1ZYHjQODNPaiftb',
#   'danceability': 0.434,
#   'energy': 0.148,
#   'key': 7,
#   'loudness': -20.672,
#   'mode': 0,
#   'speechiness': 0.0367,
#   'acousticness': 0.847,
#   'instrumentalness': 0.873,
#   'liveness': 0.126,
#   'valence': 0.0939,
#   'tempo': 127.997,
#   'duration_ms': 250587,
#   'time_signature': 4,
#   'chorus_hit': 32.51601,
#   'sections': 10,
#   'target': 0},
#  {'track': 'Work That',
#   'artist': 'Mary J. Blige',
#   'uri': 'spotify:track:3j59mQGu5USFF16v8nPNmw',
#   'danceability': 0.795,
#   'energy': 0.582,
#   'key': 5,
#   'loudness': -4.472,
#   'mode': 1,
#   'speechiness': 0.068,
#   'acousticness': 0.03,
#   'instrumentalness': 2.76e-05,
#   'liveness': 0.0806,
#   'valence': 0.627,
#   'tempo': 93.107,
#   'duration_ms': 210587,
#   'time_signature': 4,
#   'chorus_hit': 19.35307,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Holy Water',
#   'artist': 'Big & Rich',
#   'uri': 'spotify:track:4qCGe8cM5ycEKcPJdRyk3m',
#   'danceability': 0.536,
#   'energy': 0.765,
#   'key': 0,
#   'loudness': -1.991,
#   'mode': 1,
#   'speechiness': 0.0277,
#   'acousticness': 0.0451,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.344,
#   'valence': 0.456,
#   'tempo': 94.677,
#   'duration_ms': 256813,
#   'time_signature': 4,
#   'chorus_hit': 31.7809,
#   'sections': 11,
#   'target': 1},
#  {'track': 'Badd',
#   'artist': 'Ying Yang Twins Featuring Mike Jones & Mr. ColliPark',
#   'uri': 'spotify:track:1Epb6Kfe3GTgKrrWs1Y4Wy',
#   'danceability': 0.585,
#   'energy': 0.697,
#   'key': 1,
#   'loudness': -6.126,
#   'mode': 0,
#   'speechiness': 0.357,
#   'acousticness': 0.0339,
#   'instrumentalness': 0.0,
#   'liveness': 0.255,
#   'valence': 0.402,
#   'tempo': 133.177,
#   'duration_ms': 225187,
#   'time_signature': 5,
#   'chorus_hit': 31.4295,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Grounded',
#   'artist': 'Approaching Nirvana',
#   'uri': 'spotify:track:4o7K8Mb3ww0NnerXuZ2VuK',
#   'danceability': 0.279,
#   'energy': 0.259,
#   'key': 0,
#   'loudness': -11.694,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.522,
#   'instrumentalness': 0.763,
#   'liveness': 0.302,
#   'valence': 0.0364,
#   'tempo': 118.228,
#   'duration_ms': 176968,
#   'time_signature': 3,
#   'chorus_hit': 45.08377,
#   'sections': 7,
#   'target': 0},
#  {'track': 'Boyfriend #2',
#   'artist': 'Pleasure P',
#   'uri': 'spotify:track:3taIcgVjePRzkdz0ZmJbOi',
#   'danceability': 0.648,
#   'energy': 0.767,
#   'key': 8,
#   'loudness': -5.052,
#   'mode': 1,
#   'speechiness': 0.0608,
#   'acousticness': 0.0219,
#   'instrumentalness': 0.0,
#   'liveness': 0.19,
#   'valence': 0.796,
#   'tempo': 141.906,
#   'duration_ms': 207400,
#   'time_signature': 4,
#   'chorus_hit': 40.13089,
#   'sections': 7,
#   'target': 1},
#  {'track': 'Na Mohabbat Na Dosti (Waqt Rukta Nahin Kisi Ke Liye) - Phir Aayee Barsaat / Soundtrack Version',
#   'artist': 'Jagjit Singh',
#   'uri': 'spotify:track:6ni7w5q6Et96s4vBqbXLfL',
#   'danceability': 0.537,
#   'energy': 0.526,
#   'key': 10,
#   'loudness': -11.005,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.508,
#   'instrumentalness': 0.000571,
#   'liveness': 0.83,
#   'valence': 0.594,
#   'tempo': 98.155,
#   'duration_ms': 309200,
#   'time_signature': 4,
#   'chorus_hit': 45.66119,
#   'sections': 10,
#   'target': 0},
#  {'track': 'The Black Cat - Alt. Take',
#   'artist': 'London After Midnight',
#   'uri': 'spotify:track:6IQVEjfLUChdMjeUm2guMO',
#   'danceability': 0.628,
#   'energy': 0.671,
#   'key': 5,
#   'loudness': -6.273,
#   'mode': 1,
#   'speechiness': 0.0271,
#   'acousticness': 0.000623,
#   'instrumentalness': 0.762,
#   'liveness': 0.11,
#   'valence': 0.291,
#   'tempo': 112.016,
#   'duration_ms': 231333,
#   'time_signature': 3,
#   'chorus_hit': 40.20114,
#   'sections': 12,
#   'target': 0},
#  {'track': 'Tattoo',
#   'artist': 'Jordin Sparks',
#   'uri': 'spotify:track:3Ui2jdyxbZQrZohfM0NOgG',
#   'danceability': 0.566,
#   'energy': 0.766,
#   'key': 2,
#   'loudness': -5.036,
#   'mode': 1,
#   'speechiness': 0.0399,
#   'acousticness': 0.431,
#   'instrumentalness': 0.0,
#   'liveness': 0.101,
#   'valence': 0.547,
#   'tempo': 168.005,
#   'duration_ms': 233467,
#   'time_signature': 4,
#   'chorus_hit': 38.62764,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Fat Lip',
#   'artist': 'Sum 41',
#   'uri': 'spotify:track:4KacUpvbA3Mfo05gttTjhN',
#   'danceability': 0.402,
#   'energy': 0.914,
#   'key': 9,
#   'loudness': -5.215,
#   'mode': 1,
#   'speechiness': 0.142,
#   'acousticness': 0.000579,
#   'instrumentalness': 0.0,
#   'liveness': 0.065,
#   'valence': 0.626,
#   'tempo': 196.505,
#   'duration_ms': 178267,
#   'time_signature': 4,
#   'chorus_hit': 40.7393,
#   'sections': 9,
#   'target': 1},
#  {'track': 'The Way I Loved You',
#   'artist': 'Taylor Swift',
#   'uri': 'spotify:track:5P4wWhUYWM0IaVYLuZxdar',
#   'danceability': 0.433,
#   'energy': 0.7,
#   'key': 5,
#   'loudness': -3.709,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0408,
#   'instrumentalness': 0.0,
#   'liveness': 0.115,
#   'valence': 0.398,
#   'tempo': 160.927,
#   'duration_ms': 244227,
#   'time_signature': 4,
#   'chorus_hit': 25.23044,
#   'sections': 13,
#   'target': 1},
#  {'track': 'I Saw God Today',
#   'artist': 'George Strait',
#   'uri': 'spotify:track:7maV3I3KQNYpsOWYTOhGqn',
#   'danceability': 0.588,
#   'energy': 0.587,
#   'key': 3,
#   'loudness': -6.89,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.599,
#   'instrumentalness': 0.0,
#   'liveness': 0.162,
#   'valence': 0.381,
#   'tempo': 147.897,
#   'duration_ms': 203200,
#   'time_signature': 4,
#   'chorus_hit': 55.44742,
#   'sections': 8,
#   'target': 1},
#  {'track': 'Candyman',
#   'artist': 'Christina Aguilera',
#   'uri': 'spotify:track:5lUTzPuiloBHm1qEaJcJfF',
#   'danceability': 0.686,
#   'energy': 0.789,
#   'key': 8,
#   'loudness': -4.713,
#   'mode': 0,
#   'speechiness': 0.23,
#   'acousticness': 0.0125,
#   'instrumentalness': 0.0147,
#   'liveness': 0.142,
#   'valence': 0.72,
#   'tempo': 172.976,
#   'duration_ms': 194213,
#   'time_signature': 4,
#   'chorus_hit': 39.37242,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Dani California',
#   'artist': 'Red Hot Chili Peppers',
#   'uri': 'spotify:track:10Nmj3JCNoMeBQ87uw5j8k',
#   'danceability': 0.556,
#   'energy': 0.913,
#   'key': 0,
#   'loudness': -2.36,
#   'mode': 1,
#   'speechiness': 0.0437,
#   'acousticness': 0.0193,
#   'instrumentalness': 8.59e-06,
#   'liveness': 0.346,
#   'valence': 0.73,
#   'tempo': 96.184,
#   'duration_ms': 282160,
#   'time_signature': 4,
#   'chorus_hit': 53.80971,
#   'sections': 10,
#   'target': 1},
#  {'track': 'Fools Of Contradiction',
#   'artist': 'Magrudergrind',
#   'uri': 'spotify:track:1cZIYPGLFnH4TKY3tzcKO8',
#   'danceability': 0.41,
#   'energy': 0.952,
#   'key': 1,
#   'loudness': -5.98,
#   'mode': 1,
#   'speechiness': 0.205,
#   'acousticness': 7.6e-05,
#   'instrumentalness': 0.0195,
#   'liveness': 0.598,
#   'valence': 0.198,
#   'tempo': 124.926,
#   'duration_ms': 78640,
#   'time_signature': 4,
#   'chorus_hit': 49.33636,
#   'sections': 4,
#   'target': 0},
#  {'track': 'I Am Dracula - Sighisoara Tasnad Mix',
#   'artist': 'Rexanthony',
#   'uri': 'spotify:track:1QlpvejQFaiSVfIU7O1kmO',
#   'danceability': 0.476,
#   'energy': 0.949,
#   'key': 1,
#   'loudness': -9.017,
#   'mode': 1,
#   'speechiness': 0.103,
#   'acousticness': 0.00289,
#   'instrumentalness': 0.86,
#   'liveness': 0.109,
#   'valence': 0.188,
#   'tempo': 180.858,
#   'duration_ms': 235807,
#   'time_signature': 4,
#   'chorus_hit': 61.60835,
#   'sections': 11,
#   'target': 0},
#  {'track': 'The Lord of the Wasteland',
#   'artist': 'Toxic Holocaust',
#   'uri': 'spotify:track:3wrBeZiS7ZEwitbsvPUW6u',
#   'danceability': 0.181,
#   'energy': 0.959,
#   'key': 2,
#   'loudness': -4.565,
#   'mode': 1,
#   'speechiness': 0.0794,
#   'acousticness': 5.58e-06,
#   'instrumentalness': 0.851,
#   'liveness': 0.262,
#   'valence': 0.344,
#   'tempo': 192.771,
#   'duration_ms': 167693,
#   'time_signature': 4,
#   'chorus_hit': 65.24168,
#   'sections': 7,
#   'target': 0},
#  {'track': 'God Bless The USA',
#   'artist': 'Lee Greenwood',
#   'uri': 'spotify:track:1MnebCPkLm11EGCnrusLPu',
#   'danceability': 0.368,
#   'energy': 0.45,
#   'key': 5,
#   'loudness': -7.121,
#   'mode': 1,
#   'speechiness': 0.0276,
#   'acousticness': 0.156,
#   'instrumentalness': 0.0,
#   'liveness': 0.107,
#   'valence': 0.184,
#   'tempo': 139.217,
#   'duration_ms': 196933,
#   'time_signature': 4,
#   'chorus_hit': 39.13522,
#   'sections': 9,
#   'target': 1},
#  {'track': 'Hypnotized',
#   'artist': 'Plies Featuring Akon',
#   'uri': 'spotify:track:3LN41NUdHkyNqQhi9gExMm',
#   'danceability': 0.84,
#   'energy': 0.571,
#   'key': 10,
#   'loudness': -7.421,
#   'mode': 1,
#   'speechiness': 0.0797,
#   'acousticness': 0.16,
#   'instrumentalness': 0.0,
#   'liveness': 0.406,
#   'valence': 0.617,
#   'tempo': 116.59,
#   'duration_ms': 188493,
#   'time_signature': 4,
#   'chorus_hit': 37.17445,
#   'sections': 8,
#   'target': 1},
#  {'track': "Beggin'",
#   'artist': 'Madcon',
#   'uri': 'spotify:track:5SlHTXLWa0nvh8VtGgKlJB',
#   'danceability': 0.731,
#   'energy': 0.718,
#   'key': 4,
#   'loudness': -7.51,
#   'mode': 0,
#   'speechiness': 0.0672,
#   'acousticness': 0.0226,
#   'instrumentalness': 0.0,
#   'liveness': 0.0518,
#   'valence': 0.428,
#   'tempo': 129.053,
#   'duration_ms': 216520,
#   'time_signature': 4,
#   'chorus_hit': 56.88443,
#   'sections': 6,
#   'target': 1},
#  ...]

# %%
DATABASE_NAME="spotify"
COLLECTION_NAME:str="spotifydata"
MONGODB_URL_KEY=""

# %%
client=pymongo.MongoClient(MONGODB_URL_KEY)
database=client[DATABASE_NAME]
collention=database[COLLECTION_NAME]

# %%
collention.insert_many(spotify_dict)
# Out:
# InsertManyResult([ObjectId('68af2f8d33bd56507927870e'), ObjectId('68af2f8d33bd56507927870f'), ObjectId('68af2f8d33bd565079278710'), ObjectId('68af2f8d33bd565079278711'), ObjectId('68af2f8d33bd565079278712'), ObjectId('68af2f8d33bd565079278713'), ObjectId('68af2f8d33bd565079278714'), ObjectId('68af2f8d33bd565079278715'), ObjectId('68af2f8d33bd565079278716'), ObjectId('68af2f8d33bd565079278717'), ObjectId('68af2f8d33bd565079278718'), ObjectId('68af2f8d33bd565079278719'), ObjectId('68af2f8d33bd56507927871a'), ObjectId('68af2f8d33bd56507927871b'), ObjectId('68af2f8d33bd56507927871c'), ObjectId('68af2f8d33bd56507927871d'), ObjectId('68af2f8d33bd56507927871e'), ObjectId('68af2f8d33bd56507927871f'), ObjectId('68af2f8d33bd565079278720'), ObjectId('68af2f8d33bd565079278721'), ObjectId('68af2f8d33bd565079278722'), ObjectId('68af2f8d33bd565079278723'), ObjectId('68af2f8d33bd565079278724'), ObjectId('68af2f8d33bd565079278725'), ObjectId('68af2f8d33bd565079278726'), ObjectId('68af2f8d33bd565079278727'), ObjectId('68af2f8d33bd565079278728'), ObjectId('68af2f8d33bd565079278729'), ObjectId('68af2f8d33bd56507927872a'), ObjectId('68af2f8d33bd56507927872b'), ObjectId('68af2f8d33bd56507927872c'), ObjectId('68af2f8d33bd56507927872d'), ObjectId('68af2f8d33bd56507927872e'), ObjectId('68af2f8d33bd56507927872f'), ObjectId('68af2f8d33bd565079278730'), ObjectId('68af2f8d33bd565079278731'), ObjectId('68af2f8d33bd565079278732'), ObjectId('68af2f8d33bd565079278733'), ObjectId('68af2f8d33bd565079278734'), ObjectId('68af2f8d33bd565079278735'), ObjectId('68af2f8d33bd565079278736'), ObjectId('68af2f8d33bd565079278737'), ObjectId('68af2f8d33bd565079278738'), ObjectId('68af2f8d33bd565079278739'), ObjectId('68af2f8d33bd56507927873a'), ObjectId('68af2f8d33bd56507927873b'), ObjectId('68af2f8d33bd56507927873c'), ObjectId('68af2f8d33bd56507927873d'), ObjectId('68af2f8d33bd56507927873e'), ObjectId('68af2f8d33bd56507927873f'), ObjectId('68af2f8d33bd565079278740'), ObjectId('68af2f8d33bd565079278741'), ObjectId('68af2f8d33bd565079278742'), ObjectId('68af2f8d33bd565079278743'), ObjectId('68af2f8d33bd565079278744'), ObjectId('68af2f8d33bd565079278745'), ObjectId('68af2f8d33bd565079278746'), ObjectId('68af2f8d33bd565079278747'), ObjectId('68af2f8d33bd565079278748'), ObjectId('68af2f8d33bd565079278749'), ObjectId('68af2f8d33bd56507927874a'), ObjectId('68af2f8d33bd56507927874b'), ObjectId('68af2f8d33bd56507927874c'), ObjectId('68af2f8d33bd56507927874d'), ObjectId('68af2f8d33bd56507927874e'), ObjectId('68af2f8d33bd56507927874f'), ObjectId('68af2f8d33bd565079278750'), ObjectId('68af2f8d33bd565079278751'), ObjectId('68af2f8d33bd565079278752'), ObjectId('68af2f8d33bd565079278753'), ObjectId('68af2f8d33bd565079278754'), ObjectId('68af2f8d33bd565079278755'), ObjectId('68af2f8d33bd565079278756'), ObjectId('68af2f8d33bd565079278757'), ObjectId('68af2f8d33bd565079278758'), ObjectId('68af2f8d33bd565079278759'), ObjectId('68af2f8d33bd56507927875a'), ObjectId('68af2f8d33bd56507927875b'), ObjectId('68af2f8d33bd56507927875c'), ObjectId('68af2f8d33bd56507927875d'), ObjectId('68af2f8d33bd56507927875e'), ObjectId('68af2f8d33bd56507927875f'), ObjectId('68af2f8d33bd565079278760'), ObjectId('68af2f8d33bd565079278761'), ObjectId('68af2f8d33bd565079278762'), ObjectId('68af2f8d33bd565079278763'), ObjectId('68af2f8d33bd565079278764'), ObjectId('68af2f8d33bd565079278765'), ObjectId('68af2f8d33bd565079278766'), ObjectId('68af2f8d33bd565079278767'), ObjectId('68af2f8d33bd565079278768'), ObjectId('68af2f8d33bd565079278769'), ObjectId('68af2f8d33bd56507927876a'), ObjectId('68af2f8d33bd56507927876b'), ObjectId('68af2f8d33bd56507927876c'), ObjectId('68af2f8d33bd56507927876d'), ObjectId('68af2f8d33bd56507927876e'), ObjectId('68af2f8d33bd56507927876f'), ObjectId('68af2f8d33bd565079278770'), ObjectId('68af2f8d33bd565079278771'), ObjectId('68af2f8d33bd565079278772'), ObjectId('68af2f8d33bd565079278773'), ObjectId('68af2f8d33bd565079278774'), ObjectId('68af2f8d33bd565079278775'), ObjectId('68af2f8d33bd56507927 ...

# %%
loaded_df=pd.DataFrame(list(collention.find()))

# %%
loaded_df
# Out:
#                             _id                               track  \
# 0      68af2f8d33bd56507927870e                           Lucky Man
# 1      68af2f8d33bd56507927870f                      On The Hotline
# 2      68af2f8d33bd565079278710                  Clouds Of Dementia
# 3      68af2f8d33bd565079278711            Heavy Metal, Raise Hell!
# 4      68af2f8d33bd565079278712                     I Got A Feelin'
# ...                         ...                                 ...
# 41101  68af2f8d33bd56507928279b               (You're A) Go Nowhere
# 41102  68af2f8d33bd56507928279c                  La Fiebre de Norma
# 41103  68af2f8d33bd56507928279d                          Good Times
# 41104  68af2f8d33bd56507928279e                               Inane
# 41105  68af2f8d33bd56507928279f  You Can Make History (Young Again)
#
#                   artist                                   uri  danceability  \
# 0      Montgomery Gentry  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578
# 1           Pretty Ricky  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704
# 2             Candlemass  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162
# 3          Zwartketterij  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188
# 4       Billy Currington  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630
# ...                  ...                                   ...           ...
# 41101       Reagan Youth  spotify:track:4e86fqSFhqRQk3Z9hm7XHt         0.396
# 41102       La Castañeda  spotify:track:43DFcnOZprnVlAFKwgBJ3e         0.621
# 41103      Edie Brickell  spotify:track:6UPfnVoOq3y3BvapBIKs8J         0.562
# 41104              KMFDM  spotify:track:2Ao3Wi4raEOQfKQiU9EU8y         0.622
# 41105         Elton John  spotify:track:3ca91BX2k7GSzEUsx1mPgI         0.664
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0       0.471    4    -7.270     1       0.0289      0.368000
# 1       0.854   10    -5.477     0       0.1830      0.018500
# 2       0.836    9    -3.009     1       0.0473      0.000111
# 3       0.994    4    -3.745     1       0.1660      0.000007
# 4       0.764    2    -4.353     1       0.0275      0.363000
# ...       ...  ...       ...   ...          ...           ...
# 41101   0.795    9    -6.070     0       0.2340      0.000928
# 41102   0.655    9    -6.281     0       0.0309      0.050600
# 41103   0.314   10   -15.213     0       0.0298      0.440000
# 41104   0.781    7    -6.080     1       0.0368      0.000101
# 41105   0.739    2    -9.005     1       0.0262      0.106000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 0              0.000000    0.1590    0.532  133.061       196707
# 1              0.000000    0.1480    0.688   92.988       242587
# 2              0.004570    0.1740    0.300   86.964       338893
# 3              0.078400    0.1920    0.333  148.440       255667
# 4              0.000000    0.1250    0.631  112.098       193760
# ...                 ...       ...      ...      ...          ...
# 41101          0.000209    0.1820    0.762  152.943        82107
# 41102          0.006260    0.0937    0.690  134.167       211653
# 41103          0.000011    0.1060    0.571  166.847       189827
# 41104          0.755000    0.3830    0.214  120.051       330053
# 41105          0.054200    0.3330    0.458   92.257       293973
#
#        time_signature  chorus_hit  sections  target
# 0                   4    30.88059        13       1
# 1                   4    41.51106        10       1
# 2                   4    65.32887        13       0
# 3                   4    58.59528         9       0
# 4                   4    22.62384        10       1
# ...               ...         ...       ...     ...
# 41101               4    30.34109         6       0
# 41102               4    34.89506        10       0
# 41103               4    21.11763        10       1
# 41104               4    47.13558        11       0
# 41105               4    42.50341        14       1
#
# [41106 rows x 20 columns]
